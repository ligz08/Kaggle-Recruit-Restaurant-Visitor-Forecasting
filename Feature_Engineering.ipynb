# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Load-data-from-scratch-folder" data-toc-modified-id="Load-data-from-scratch-folder-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load data from <code>scratch</code> folder</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Date-features-of-full.visit_date" data-toc-modified-id="Date-features-of-full.visit_date-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Date features of <code>full.visit_date</code></a></span><ul class="toc-item"><li><span><a href="#Year,-month,-weekday,-etc" data-toc-modified-id="Year,-month,-weekday,-etc-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Year, month, weekday, etc</a></span></li><li><span><a href="#Days-since-beginnning" data-toc-modified-id="Days-since-beginnning-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Days since beginnning</a></span></li><li><span><a href="#Holiday-flag" data-toc-modified-id="Holiday-flag-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Holiday flag</a></span></li><li><span><a href="#Long-holiday" data-toc-modified-id="Long-holiday-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Long holiday</a></span></li></ul></li><li><span><a href="#Location-of-stores" data-toc-modified-id="Location-of-stores-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Location of <code>stores</code></a></span><ul class="toc-item"><li><span><a href="#Split-area_name-string-to-get-different-levels-of-location-names" data-toc-modified-id="Split-area_name-string-to-get-different-levels-of-location-names-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Split <code>area_name</code> string to get different levels of location names</a></span></li><li><span><a href="#Count-stores-in-the-same-location" data-toc-modified-id="Count-stores-in-the-same-location-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Count stores in the same location</a></span></li><li><span><a href="#Add-store-info-to-full" data-toc-modified-id="Add-store-info-to-full-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Add store info to <code>full</code></a></span></li></ul></li><li><span><a href="#Reservation-features" data-toc-modified-id="Reservation-features-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Reservation features</a></span><ul class="toc-item"><li><span><a href="#Each-reservation" data-toc-modified-id="Each-reservation-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Each reservation</a></span></li><li><span><a href="#Reservation-summary-for-each-planned-visit-date" data-toc-modified-id="Reservation-summary-for-each-planned-visit-date-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Reservation summary for each planned visit date</a></span></li><li><span><a href="#Add-reserve_summary-to-full" data-toc-modified-id="Add-reserve_summary-to-full-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Add <code>reserve_summary</code> to <code>full</code></a></span></li></ul></li><li><span><a href="#Interactions-between-features" data-toc-modified-id="Interactions-between-features-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Interactions between features</a></span><ul class="toc-item"><li><span><a href="#Numeric-numeric-interaction" data-toc-modified-id="Numeric-numeric-interaction-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Numeric-numeric interaction</a></span></li><li><span><a href="#Combos-of-cat-features" data-toc-modified-id="Combos-of-cat-features-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Combos of cat features</a></span></li></ul></li><li><span><a href="#Aggregation-of-target-variable" data-toc-modified-id="Aggregation-of-target-variable-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Aggregation of target variable</a></span></li></ul></li><li><span><a href="#Reformat-Features" data-toc-modified-id="Reformat-Features-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Reformat Features</a></span><ul class="toc-item"><li><span><a href="#Types-of-features-(cat,-num,-etc.)" data-toc-modified-id="Types-of-features-(cat,-num,-etc.)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Types of features (cat, num, etc.)</a></span></li><li><span><a href="#Cat-features:-label→int-encoding-&amp;-one-hot-encoding" data-toc-modified-id="Cat-features:-label→int-encoding-&amp;-one-hot-encoding-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cat features: label→int encoding &amp; one-hot encoding</a></span><ul class="toc-item"><li><span><a href="#Label-encoding" data-toc-modified-id="Label-encoding-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Label encoding</a></span></li><li><span><a href="#One-hot-encoding" data-toc-modified-id="One-hot-encoding-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>One-hot encoding</a></span></li></ul></li></ul></li><li><span><a href="#Save-Engineered-Dataset-to-Pickle-Files" data-toc-modified-id="Save-Engineered-Dataset-to-Pickle-Files-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Save Engineered Dataset to Pickle Files</a></span></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn

# %% [markdown]
# ## Load data from `scratch` folder

# %%
full = pd.read_csv('scratch/full.csv', parse_dates=['visit_date'])
display(full.head())
display(full.info())
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors
# 0        25
# 1        32
# 2        29
# 3        22
# 4         6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284127 entries, 0 to 284126
# Data columns (total 5 columns):
# dataset         284127 non-null object
# air_store_id    284127 non-null object
# id              284127 non-null object
# visit_date      284127 non-null datetime64[ns]
# visitors        284127 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 10.8+ MB
# None

# %% [markdown]
# ## Feature Engineering

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors
# 0        25
# 1        32
# 2        29
# 3        22
# 4         6

# %% [markdown]
# ### Date features of `full.visit_date`

# %% [markdown]
# #### Year, month, weekday, etc

# %%
full['weekday'] = full.visit_date.dt.dayofweek
full['year'] = full.visit_date.dt.year
full['month'] = full.visit_date.dt.month
full['day_of_year'] = full.visit_date.dt.dayofyear
full['days_in_month'] = full.visit_date.dt.days_in_month
full['week_of_year'] = full.visit_date.dt.weekofyear
full['is_month_end'] = full.visit_date.dt.is_month_end

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month  week_of_year  \
# 0        25        2  2016      1           13             31             2
# 1        32        3  2016      1           14             31             2
# 2        29        4  2016      1           15             31             2
# 3        22        5  2016      1           16             31             2
# 4         6        0  2016      1           18             31             3
#
#    is_month_end
# 0         False
# 1         False
# ...

# %% [markdown]
# #### Days since beginnning

# %%
full.visit_date.min()
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
first_day = pd.to_datetime('2016-01-01')

# %%
full['days_since_20160101'] = (full.visit_date - first_day).apply(lambda dt: dt.days)

# %% [markdown]
# #### Holiday flag

# %%
holiday_info = pd.read_csv('input/date_info.csv',  
                           parse_dates=['calendar_date'])

# %%
holiday_info.head()
# Out:
#   calendar_date day_of_week  holiday_flg
# 0    2016-01-01      Friday            1
# 1    2016-01-02    Saturday            1
# 2    2016-01-03      Sunday            1
# 3    2016-01-04      Monday            0
# 4    2016-01-05     Tuesday            0

# %%
holiday_info['tomorrow_is_holiday'] = holiday_info.holiday_flg.shift(-1).fillna(0).astype(int)
holiday_info['yesterday_is_holiday'] = holiday_info.holiday_flg.shift(1).fillna(0).astype(int)

# %%
full = pd.merge(left=full, 
                right=holiday_info.drop('day_of_week', axis=1), 
                how='left', 
                left_on='visit_date', right_on='calendar_date')\
        .drop('calendar_date', axis=1)

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month  week_of_year  \
# 0        25        2  2016      1           13             31             2
# 1        32        3  2016      1           14             31             2
# 2        29        4  2016      1           15             31             2
# 3        22        5  2016      1           16             31             2
# 4         6        0  2016      1           18             31             3
#
# ...

# %% [markdown]
# ### Location of `stores`

# %%
stores = pd.read_csv('scratch/stores.csv')

# %% [markdown]
# #### Split `area_name` string to get different levels of location names

# %%
area_split = stores.air_area_name.str.split(' ', expand=True)

stores['Todofuken'] = area_split[0]
stores['city'] = area_split[1]
stores['street'] = area_split.iloc[:, 2:].apply(lambda row: ' '.join(row.dropna()), axis=1)

# %%
stores.head()
# Out:
#            air_store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen
#
#    latitude_air  longitude_air          hpg_store_id hpg_genre_name  \
# 0     34.695124     135.197852                   NaN            NaN
# 1     34.695124     135.197852  hpg_9b38b9e13da6da27            NaN
# 2     34.695124     135.197852                   NaN            NaN
# 3     34.695124     135.197852                   NaN            NaN
# 4     35.658068     139.751599                   NaN            NaN
#
#   hpg_area_name  latitude_hpg  longitude_hpg  Todofuken       city     street
# ...

# %% [markdown]
# #### Count stores in the same location

# %%
n_stores_by_street = stores.groupby(['air_area_name']).size().to_frame(name='n_stores_same_street').reset_index()
n_stores_by_city = stores.groupby(['Todofuken', 'city']).size().to_frame(name='n_stores_same_city').reset_index()
n_stores_by_Todofuken = stores.groupby('Todofuken').size().to_frame(name='n_stores_same_Todofuken').reset_index()

# %% [markdown]
# Same street:

# %%
n_stores_by_street.head()
# Out:
#                            air_area_name  n_stores_same_street
# 0         Fukuoka-ken Fukuoka-shi Daimyō                    64
# 1  Fukuoka-ken Fukuoka-shi Hakata Ekimae                    16
# 2       Fukuoka-ken Fukuoka-shi Imaizumi                     2
# 3        Fukuoka-ken Fukuoka-shi Momochi                     6
# 4       Fukuoka-ken Fukuoka-shi Shiobaru                     7

# %% [markdown]
# Same city:

# %%
n_stores_by_city.head()
# Out:
#      Todofuken            city  n_stores_same_city
# 0  Fukuoka-ken     Fukuoka-shi                 103
# 1  Fukuoka-ken    Itoshima-shi                   7
# 2  Fukuoka-ken  Kitakyūshū-shi                   9
# 3  Fukuoka-ken      Kurume-shi                   6
# 4  Fukuoka-ken        Yame-shi                   2

# %% [markdown]
# Same Todofuken:

# %%
n_stores_by_Todofuken
# Out:
#        Todofuken  n_stores_same_Todofuken
# 0    Fukuoka-ken                      127
# 1  Hiroshima-ken                       32
# 2       Hokkaidō                       46
# 3      Hyōgo-ken                       57
# 4     Miyagi-ken                       17
# 5    Niigata-ken                       14
# 6   Shizuoka-ken                       18
# 7       Tōkyō-to                      444
# 8       Ōsaka-fu                       74

# %%
stores = pd.merge(left=stores, right=n_stores_by_street, how='left', on='air_area_name')
stores = pd.merge(left=stores, right=n_stores_by_city, how='left', on=['Todofuken', 'city'])
stores = pd.merge(left=stores, right=n_stores_by_Todofuken, how='left', on='Todofuken')

# %%
stores.head()
# Out:
#            air_store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen
#
#    latitude_air  longitude_air          hpg_store_id hpg_genre_name  \
# 0     34.695124     135.197852                   NaN            NaN
# 1     34.695124     135.197852  hpg_9b38b9e13da6da27            NaN
# 2     34.695124     135.197852                   NaN            NaN
# 3     34.695124     135.197852                   NaN            NaN
# 4     35.658068     139.751599                   NaN            NaN
#
#   hpg_area_name  latitude_hpg  longitude_hpg  Todofuken       city     street  \
# ...

# %% [markdown]
# #### Add store info to `full`

# %%
full = pd.merge(left=full, right=stores, how='left', on='air_store_id')

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month  \
# 0        25        2  2016      1           13             31
# 1        32        3  2016      1           14             31
# 2        29        4  2016      1           15             31
# 3        22        5  2016      1           16             31
# 4         6        0  2016      1           18             31
#
#             ...             hpg_genre_name  hpg_area_name  latitude_hpg  \
# ...

# %% [markdown]
# ### Reservation features

# %%
reserves = pd.read_csv('scratch/reserves.csv', parse_dates=['visit_datetime', 'reserve_datetime'])

# %%
display(reserves.head())
display(reserves.info())
# Out:
#            air_store_id      visit_datetime    reserve_datetime  \
# 0  air_877f79706adbfb06 2016-01-01 19:00:00 2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 3  air_877f79706adbfb06 2016-01-01 20:00:00 2016-01-01 16:00:00
# 4  air_db80363d35f10926 2016-01-01 20:00:00 2016-01-01 01:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 6
# 3                 2
# 4                 5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120561 entries, 0 to 120560
# Data columns (total 4 columns):
# air_store_id        120561 non-null object
# visit_datetime      120561 non-null datetime64[ns]
# reserve_datetime    120561 non-null datetime64[ns]
# reserve_visitors    120561 non-null int64
# dtypes: datetime64[ns](2), int64(1), object(1)
# memory usage: 3.7+ MB
# None

# %% [markdown]
# #### Each reservation

# %%
reserves['planned_visit_date'] = reserves.visit_datetime.dt.date.astype('datetime64[ns]')
reserves['reserve_date'] = reserves.reserve_datetime.dt.date
reserves['reserve_ahead'] = reserves.visit_datetime - reserves.reserve_datetime.astype('datetime64[ns]')
reserves['hours_ahead'] = reserves.reserve_ahead / pd.Timedelta('1 hour')
reserves['days_ahead'] = reserves.reserve_ahead.apply(lambda delta_t: delta_t.days)

# %%
display(reserves.head())
display(reserves.info())
# Out:
#            air_store_id      visit_datetime    reserve_datetime  \
# 0  air_877f79706adbfb06 2016-01-01 19:00:00 2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff 2016-01-01 19:00:00 2016-01-01 19:00:00
# 3  air_877f79706adbfb06 2016-01-01 20:00:00 2016-01-01 16:00:00
# 4  air_db80363d35f10926 2016-01-01 20:00:00 2016-01-01 01:00:00
#
#    reserve_visitors planned_visit_date reserve_date reserve_ahead  \
# 0                 1         2016-01-01   2016-01-01      03:00:00
# 1                 3         2016-01-01   2016-01-01      00:00:00
# 2                 6         2016-01-01   2016-01-01      00:00:00
# 3                 2         2016-01-01   2016-01-01      04:00:00
# 4                 5         2016-01-01   2016-01-01      19:00:00
#
#    hours_ahead  days_ahead
# 0          3.0           0
# 1          0.0           0
# 2          0.0           0
# 3          4.0           0
# 4         19.0           0
# ...

# %% [markdown]
# #### Reservation summary for each planned visit date

# %% [markdown]
# - How many reserves?
# - How many visitors plan to visit?
# - How early did they reserve?

# %%
reserve_summary = reserves\
                        .groupby(['air_store_id', 'planned_visit_date'])\
                        ['reserve_visitors', 'hours_ahead']\
                        .agg({'reserve_visitors': ['count','sum'], 'hours_ahead': 'mean'})\
                        .reset_index()
reserve_summary.columns=['air_store_id', 'planned_visit_date', 
                     'n_reserves', 'n_reserve_visitors', 'reserve_avg_hours_ahead']

# %%
reserve_summary.head()
# Out:
#            air_store_id planned_visit_date  n_reserves  n_reserve_visitors  \
# 0  air_00a91d42b08b08d9         2016-01-14           1                   2
# 1  air_00a91d42b08b08d9         2016-01-15           1                   4
# 2  air_00a91d42b08b08d9         2016-01-16           1                   2
# 3  air_00a91d42b08b08d9         2016-01-22           1                   2
# 4  air_00a91d42b08b08d9         2016-01-29           1                   5
#
#    reserve_avg_hours_ahead
# 0                     77.0
# 1                    142.0
# 2                     70.0
# 3                     82.0
# 4                    144.0

# %% [markdown]
# #### Add `reserve_summary` to `full`

# %%
full = pd.merge(left=full, right=reserve_summary, how='left', 
                left_on=['air_store_id', 'visit_date'], 
                right_on=['air_store_id', 'planned_visit_date'])

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month  \
# 0        25        2  2016      1           13             31
# 1        32        3  2016      1           14             31
# 2        29        4  2016      1           15             31
# 3        22        5  2016      1           16             31
# 4         6        0  2016      1           18             31
#
#             ...             Todofuken       city     street  \
# 0           ...              Tōkyō-to  Minato-ku  Shibakōen
# ...

# %% [markdown]
# A fairly big portion of the stores & dates to predict don't have any reservations.

# %%
full.n_reserves.isnull().mean()
# Out:
# 0.86989268883281068

# %% [markdown]
# ### Interactions between features

# %% [markdown]
# #### Numeric-numeric interaction

# %% [markdown]
# #### Combos of cat features

# %%
def catStrFeatures(df, colname1, colname2, sep='_'):
    series = df[colname1].astype(str).str.cat(df[colname2].astype(str), sep=sep)
    return series

# %%
full['area_genre'] = catStrFeatures(full, 'air_area_name', 'air_genre_name')
full['store_weekday'] = catStrFeatures(full, 'air_store_id', 'weekday')
full['store_weekday_holiday'] = catStrFeatures(full, 'store_weekday', 'holiday_flg')

# %% [markdown]
# ### Aggregation of target variable

# %% [markdown]
# Find the mean, median, max, min of `visitors` for each store-weekday-holiday combination.
# The idea is to provide a very rough range estimate of # visitors based on historic statistics.

# %%
group_by_cols = ['air_store_id', 'weekday', 'holiday_flg']

visitor_stats = full\
                .query('dataset == "past"')\
                .groupby(group_by_cols)\
                ['visitors']\
                .agg(['mean', 'median', 'min', 'max'])\
                .rename(columns=lambda colname: str(colname)+'_visitors')\
                .reset_index()

# %%
full = full.merge(visitor_stats, how='left', on=group_by_cols)

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month      ...       \
# 0        25        2  2016      1           13             31      ...
# 1        32        3  2016      1           14             31      ...
# 2        29        4  2016      1           15             31      ...
# 3        22        5  2016      1           16             31      ...
# 4         6        0  2016      1           18             31      ...
#
#    n_reserves  n_reserve_visitors  reserve_avg_hours_ahead  \
# ...

# %% [markdown]
# ## Reformat Features

# %%
full.head()
# Out:
#   dataset          air_store_id                               id visit_date  \
# 0    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-13 2016-01-13
# 1    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-14 2016-01-14
# 2    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-15 2016-01-15
# 3    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-16 2016-01-16
# 4    past  air_ba937bf13d40fb24  air_ba937bf13d40fb24_2016-01-18 2016-01-18
#
#    visitors  weekday  year  month  day_of_year  days_in_month      ...       \
# 0        25        2  2016      1           13             31      ...
# 1        32        3  2016      1           14             31      ...
# 2        29        4  2016      1           15             31      ...
# 3        22        5  2016      1           16             31      ...
# 4         6        0  2016      1           18             31      ...
#
#    n_reserves  n_reserve_visitors  reserve_avg_hours_ahead  \
# ...

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284127 entries, 0 to 284126
# Data columns (total 42 columns):
# dataset                    284127 non-null object
# air_store_id               284127 non-null object
# id                         284127 non-null object
# visit_date                 284127 non-null datetime64[ns]
# visitors                   284127 non-null int64
# weekday                    284127 non-null int64
# year                       284127 non-null int64
# month                      284127 non-null int64
# day_of_year                284127 non-null int64
# days_in_month              284127 non-null int64
# week_of_year               284127 non-null int64
# is_month_end               284127 non-null bool
# days_since_20160101        284127 non-null int64
# holiday_flg                284127 non-null int64
# tomorrow_is_holiday        284127 non-null int32
# yesterday_is_holiday       284127 non-null int32
# air_genre_name             284127 non-null object
# ...

# %%
full.columns
# Out:
# Index(['dataset', 'air_store_id', 'id', 'visit_date', 'visitors', 'weekday',
#        'year', 'month', 'day_of_year', 'days_in_month', 'week_of_year',
#        'is_month_end', 'days_since_20160101', 'holiday_flg',
#        'tomorrow_is_holiday', 'yesterday_is_holiday', 'air_genre_name',
#        'air_area_name', 'latitude_air', 'longitude_air', 'hpg_store_id',
#        'hpg_genre_name', 'hpg_area_name', 'latitude_hpg', 'longitude_hpg',
#        'Todofuken', 'city', 'street', 'n_stores_same_street',
#        'n_stores_same_city', 'n_stores_same_Todofuken', 'planned_visit_date',
#        'n_reserves', 'n_reserve_visitors', 'reserve_avg_hours_ahead',
#        'area_genre', 'store_weekday', 'store_weekday_holiday', 'mean_visitors',
#        'median_visitors', 'min_visitors', 'max_visitors'],
#       dtype='object')

# %% [markdown]
# ### Types of features (cat, num, etc.)

# %%
# categorical columns
cat_cols = ['air_store_id', 'air_genre_name', 'air_area_name', 
            'hpg_genre_name', 'hpg_area_name',
            'Todofuken', 'city', 'street', 
            'area_genre', 'store_weekday', 'store_weekday_holiday'
           ]

# binary columns (T/F or 1/0)
bin_cols = ['is_month_end', 'holiday_flg', 'tomorrow_is_holiday', 'yesterday_is_holiday']

# numeric columns
num_cols = ['weekday', 'year', 'month', 'day_of_year', 'days_in_month', 'week_of_year', 'days_since_20160101', # date
            'latitude_air', 'longitude_air',   # location
            'n_stores_same_street', 'n_stores_same_city', 'n_stores_same_Todofuken',    # neighbor
            'n_reserves', 'n_reserve_visitors', 'reserve_avg_hours_ahead',  # reserves
            'mean_visitors', 'median_visitors', 'min_visitors', 'max_visitors'    # simple aggregation of visitors
           ]    

# id columns
id_col = 'id'

# target column
target_col = 'visitors'

# %% [markdown]
# ### Cat features: label→int encoding & one-hot encoding

# %% [markdown]
# #### Label encoding
# Categorical/string label → integer

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat2int_cols = [ cat+'_int' for cat in cat_cols ]    
# a list of column names (strings) 
# to keep track of all columns turned from categorical to integer

cat2int_encoders = {}
# a dict of LabelEncoder objects 
# e.g. {'air_store_id': LabelEncoder().fit_transform(full['air_store_id'])}
# used for transforming (and inverse transforming) the encoding of each cat feature

# %%
# %%time

for cat, cat2int in zip(cat_cols, cat2int_cols):
    encoder = LabelEncoder()
    full[cat2int] = encoder.fit_transform(full[cat].astype(str))
    cat2int_encoders[cat] = encoder
# Out:
# Wall time: 2.19 s

# %%
full[cat2int_cols].head()
# Out:
#    air_store_id_int  air_genre_name_int  air_area_name_int  \
# 0               603                   4                 62
# 1               603                   4                 62
# 2               603                   4                 62
# 3               603                   4                 62
# 4               603                   4                 62
#
#    hpg_genre_name_int  hpg_area_name_int  Todofuken_int  city_int  street_int  \
# 0                  16                 31              7        29          77
# 1                  16                 31              7        29          77
# 2                  16                 31              7        29          77
# 3                  16                 31              7        29          77
# 4                  16                 31              7        29          77
#
#    area_genre_int  store_weekday_int  store_weekday_holiday_int
# 0             144               4222                       7860
# ...

# %% [markdown]
# #### One-hot encoding
# Integer label → columns of 0/1
#
# The output one-hot codes matrix is going to be very very sparse,
# so use the `sparse=True` option of `OneHotEncoder()` to output a sparse matrix.

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# %%time
onehot_encoder = OneHotEncoder(sparse=True)
cat2onehot_sparse = onehot_encoder.fit_transform(full[cat2int_cols])
# Out:
# Wall time: 205 ms

# %%
cat2onehot_sparse.shape
# Out:
# (284127, 18026)

# %%
len(cat_cols)
# Out:
# 11

# %% [markdown]
# The 11 categorical columns generated 18K one-hot columns!

# %%
cat2onehot_cols = [ cat+'__is__'+str(level).replace(' ', '_') 
                   for cat in cat_cols for level in cat2int_encoders[cat].classes_]

# %%
import random
random.sample(cat2onehot_cols, 20)
# Out:
# ['store_weekday_holiday__is__air_87078cf7903a648c_1_0',
#  'store_weekday_holiday__is__air_bebd55ed63ab2422_6_0',
#  'store_weekday_holiday__is__air_3f91d592acd6cc0b_5_0',
#  'store_weekday_holiday__is__air_7d65049f9d275c0d_0_0',
#  'store_weekday_holiday__is__air_68147db09287bf74_5_0',
#  'store_weekday_holiday__is__air_eca5e0064dc9314a_4_1',
#  'store_weekday_holiday__is__air_e5cf003abcc5febb_3_0',
#  'store_weekday__is__air_ef920fa6f4b085f6_2',
#  'store_weekday_holiday__is__air_ebe02c3090271fa9_2_1',
#  'store_weekday_holiday__is__air_7420042ff75f9aca_0_1',
#  'store_weekday__is__air_7420042ff75f9aca_1',
#  'store_weekday__is__air_a9178f19da58fe99_2',
#  'store_weekday_holiday__is__air_ee3a01f0c71a769f_2_0',
#  'store_weekday__is__air_3561fd1c0bce6a95_1',
#  'store_weekday__is__air_728ff578acc6ac6e_3',
#  'store_weekday__is__air_f183a514cb8ff4fa_4',
#  'store_weekday_holiday__is__air_36429b5ca4407b3e_1_0',
#  'store_weekday__is__air_c6a164dd4060e960_6',
# ...

# %% [markdown]
# ## Save Engineered Dataset to Pickle Files

# %%
import os
import pickle
if not os.path.exists('scratch'): os.mkdir('scratch')

# %%
full.to_pickle('scratch/full_engineered.pkl')

with open('scratch/variables.pkl', 'wb') as f:
    pickle.dump([cat_cols, num_cols, bin_cols, id_col, target_col,
                 cat2int_cols, cat2int_encoders, cat2onehot_cols,
                 cat2onehot_sparse], f)
